# %%
# %set_env DATABASE_URL=postgres://sjxgnmkszhvvdc:d8add5033b1fec41278632fc2d7c50ddd0a28f07f066c9e3589cee6dbda7974c@ec2-174-129-33-181.compute-1.amazonaws.com:5432/d8oipsseui1nq1
# Out:
# env: DATABASE_URL=postgres://sjxgnmkszhvvdc:d8add5033b1fec41278632fc2d7c50ddd0a28f07f066c9e3589cee6dbda7974c@ec2-174-129-33-181.compute-1.amazonaws.com:5432/d8oipsseui1nq1

# %% [markdown]
# The next line sets environment variable for SQL database.

# %%
# %env
# Out:
# {'CLICOLOR': '1',
#  'CLOUDSDK_CONFIG': '/content/.config',
#  'COLAB_GPU': '0',
#  'CUDA_PKG_VERSION': '10-1=10.1.243-1',
#  'CUDA_VERSION': '10.1.243',
#  'CUDNN_VERSION': '7.6.5.32',
#  'DATABASE_URL': 'postgres://sjxgnmkszhvvdc:d8add5033b1fec41278632fc2d7c50ddd0a28f07f066c9e3589cee6dbda7974c@ec2-174-129-33-181.compute-1.amazonaws.com:5432/d8oipsseui1nq1',
#  'DATALAB_SETTINGS_OVERRIDES': '{"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\\"172.28.0.2\\""]}',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'ENV': '/root/.bashrc',
#  'GCS_READ_CACHE_BLOCK_SIZE_MB': '16',
#  'GIT_PAGER': 'cat',
#  'GLIBCPP_FORCE_NEW': '1',
#  'GLIBCXX_FORCE_NEW': '1',
#  'HOME': '/root',
#  'HOSTNAME': 'eebdbcaae0fd',
#  'JPY_PARENT_PID': '18',
#  'LANG': 'en_US.UTF-8',
#  'LAST_FORCED_REBUILD': '20191217',
#  'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#  'LD_PRELOAD': '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4',
# ...

# %%
import os

from sqlalchemy import create_engine
from sqlalchemy.orm import scoped_session, sessionmaker

engine = create_engine(os.getenv("DATABASE_URL"))

# db_url_string = "postgres://sjxgnmkszhvvdc:d8add5033b1fec41278632fc2d7c50ddd0a28f07f066c9e3589cee6dbda7974c@ec2-174-129-33-181.compute-1.amazonaws.com:5432/d8oipsseui1nq1"
# engine = create_engine(db_url_string)

db = scoped_session(sessionmaker(bind=engine))

def main():
    flights = db.execute("SELECT origin, destination, duration FROM flights").fetchall()
    for flight in flights:
        print(f"{flight.origin} to {flight.destination}, {flight.duration} minutes.")

if __name__ == "__main__":
    main()
# Out:
# Shanghai to Paris, 760 minutes.
# Moscow to Paris, 245 minutes.
# Lima to New York, 455 minutes.
# Huntsville to Atlanta, 45 minutes.
# New York to Paris, 427 minutes.
# New York to London, 415 minutes.
# Istanbul to Tokyo, 700 minutes.

# %%
print(os.getenv("DATABASE_URL"))
# Out:
# None

# %%
# !pip install psycopg2-binary
# Out:
# ...
#      |████████████████████████████████| 2.9MB 2.6MB/s
# ...
