# %% [markdown]
# # CS50W Week 4 ORMS and APIs
# This is mainly a scratchpad where I attempt to solve issues concurrently with watching the class videos.

# %% [markdown]
# ## Define a class "flight" with id, origin, destination, and duration
#
# double click to see solution
# <!-- class flight():
#     def __init__(self,id,origin,destination,duration):
#         self.id = id
#         self.origin = origin
#         self.destination = destination
#         self.duration = duration
#
# f191 = flight(191,'Miami','Jacksonville',15)
#
# print(f191.destination)
#
# -->

# %%
class flight:
    def __init__(self,id, origin, destination, duration):
        self.id = id
        self.origin = origin
        self.destination = destination
        self.duration = duration

f191 = flight(191,'Austin', 'Nashville',150)

f191.origin
# Out:
# 'Austin'

# %%
f191.destination
# Out:
# 'Cuba'

# %%
f191.x
# Out:
# 6
